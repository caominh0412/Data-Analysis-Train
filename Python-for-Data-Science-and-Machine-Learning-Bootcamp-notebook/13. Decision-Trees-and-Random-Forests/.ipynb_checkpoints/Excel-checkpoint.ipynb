# %%
import pandas as pd

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
df = pd.read_excel(r"V:\2.SXMOI\TTKD LifeStyle\Super\_HOME\__________HO TRO\190517_Minh\190509_137008_An My_103sku (Quyen).xlsx")

# %%
df.dropna(axis=1,inplace=True,how='all')

# %%
df.head()
# Out:
#   THÔNG TIN THUỘC TÍNH CƠ BẢN                   Unnamed: 1  \
# 0                         STT                 Mã HH -  NCC
# 1                           1                            2
# 2                         NaN  Là mã sản phẩm NCC quản lý.
# 3                           1                 7584701501-1
# 4                           2                 7584701501-2
#
#                                           Unnamed: 2  \
# 0                                            Barcode
# 1                                                  3
# 2  Là mã vạch của sản phẩm, nếu NCC không có mã H...
# 3                                       7584701501-1
# 4                                       7584701501-2
#
#                                           Unnamed: 3   Unnamed: 4  \
# 0              Tên Sản phẩm (Tiếng Việt + Tiếng Anh)  Đơn vị tính
# 1                                                  4            5
# 2  Tên thông dụng của sản phẩm bao gồm tên gọi ti...          NaN
# ...

# %%
a = pd.DataFrame(columns=df.iloc[2],data=df.iloc[4:])

# %%
df.columns=df.iloc[2]

# %%
df.drop([0,1,2,3],axis=0,inplace=True)

# %%
df.head()
# Out:
# 2 NaN Là mã sản phẩm NCC quản lý.  \
# 4   2                7584701501-2
# 5   3                7584701501-4
# 6   4                7584701522-1
# 7   5                7584701522-2
# 8   6                7584701522-4
#
# 2 Là mã vạch của sản phẩm, nếu NCC không có mã HH thì barcode = mã SKU  \
# 4                                       7584701501-2
# 5                                       7584701501-4
# 6                                       7584701522-1
# 7                                       7584701522-2
# 8                                       7584701522-4
#
# 2 Tên thông dụng của sản phẩm bao gồm tên gọi tiếng Việt và tên tiếng Anh (nếu có)  \
# 4  Bình xịt khử mùi Ozium Air Sanitizer Spray 3.5...
# 5  Bình xịt khử mùi Ozium Air Sanitizer Spray 3.5...
# 6  Bình xịt khử mùi Ozium Air Sanitizer Spray 3.5...
# 7  Bình xịt khử mùi Ozium Air Sanitizer Spray 3.5...
# 8  Bình xịt khử mùi Ozium Air Sanitizer Spray 3.5...
#
# 2     NaN  \
# 4  2 chai
# 5  4 chai
# 6  1 chai
# ...

# %%
from Getlinkchung import getImg_frompandas

# %%
getImg_frompandas(df['Là mã sản phẩm NCC quản lý.'].iloc[4],df['Link thông tin tham khảo chính thức của từng sản phẩm'].iloc[4])
# Out:
# PROCESSING: https://anmy.com.vn/products/ozium-air-sanitizer-spray-3-5-oz-99g-new-car-ozm-22
# ERROR - Cant get link https://anmy.com.vn/products/ozium-air-sanitizer-spray-3-5-oz-99g-new-car-ozm-22
# '7584701522-4'
